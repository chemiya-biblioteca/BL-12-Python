# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.preprocessing import Binarizer, MinMaxScaler
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
datos = load_wine()

# %%
df = pd.DataFrame(columns=[datos.feature_names], data=datos.data)
df.insert(loc=len(df.columns), column="Class", value=datos.target)
df
# Out:
#     alcohol malic_acid   ash alcalinity_of_ash magnesium total_phenols  \
# 0     14.23       1.71  2.43              15.6     127.0          2.80
# 1     13.20       1.78  2.14              11.2     100.0          2.65
# 2     13.16       2.36  2.67              18.6     101.0          2.80
# 3     14.37       1.95  2.50              16.8     113.0          3.85
# 4     13.24       2.59  2.87              21.0     118.0          2.80
# ..      ...        ...   ...               ...       ...           ...
# 173   13.71       5.65  2.45              20.5      95.0          1.68
# 174   13.40       3.91  2.48              23.0     102.0          1.80
# 175   13.27       4.28  2.26              20.0     120.0          1.59
# 176   13.17       2.59  2.37              20.0     120.0          1.65
# 177   14.13       4.10  2.74              24.5      96.0          2.05
#
#     flavanoids nonflavanoid_phenols proanthocyanins color_intensity   hue  \
# ...

# %%
X = MinMaxScaler().fit_transform(np.array(df.iloc[:, :-1], dtype=float))
y = np.array(df.iloc[:,-1], dtype=int)

# %%
EPOCHS = 50
#creo mlp
model = MLPClassifier(hidden_layer_sizes=(64,), solver='sgd', batch_size=1, 
                      max_iter=178*EPOCHS, learning_rate_init=0.01, verbose=True, tol=1e-8)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=1/3, stratify=y)

# %%
model.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.68950283
# Iteration 2, loss = 0.21725624
# Iteration 3, loss = 0.10213087
# Iteration 4, loss = 0.12712814
# Iteration 5, loss = 0.10636618
# Iteration 6, loss = 0.07736103
# Iteration 7, loss = 0.06665733
# Iteration 8, loss = 0.05147021
# Iteration 9, loss = 0.03530024
# Iteration 10, loss = 0.02906661
# Iteration 11, loss = 0.05772954
# Iteration 12, loss = 0.03068115
# Iteration 13, loss = 0.06078970
# Iteration 14, loss = 0.04209958
# Iteration 15, loss = 0.03006156
# Iteration 16, loss = 0.03116854
# Iteration 17, loss = 0.02270926
# Iteration 18, loss = 0.01696127
# Iteration 19, loss = 0.01706425
# Iteration 20, loss = 0.01798485
# Iteration 21, loss = 0.01679709
# Iteration 22, loss = 0.01470063
# Iteration 23, loss = 0.01398895
# Iteration 24, loss = 0.01312391
# Iteration 25, loss = 0.01291980
# Iteration 26, loss = 0.01463820
# Iteration 27, loss = 0.01348286
# Iteration 28, loss = 0.01378727
# Iteration 29, loss = 0.01186077
# ...

# %%
accuracy_score(model.predict(X_test), y_test)
# Out:
# 0.95

# %%
model?
# Out:
# Type:        MLPClassifier
# String form:
# MLPClassifier(batch_size=1, hidden_layer_sizes=(64,), learning_rate_init=0.01,
#               max_iter=8900, solver='sgd', tol=1e-08, verbose=True)
# File:        ~/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py
# Docstring:
# Multi-layer Perceptron classifier.
#
# This model optimizes the log-loss function using LBFGS or stochastic
# gradient descent.
#
# .. versionadded:: 0.18
#
# Parameters
# ----------
# hidden_layer_sizes : tuple, length = n_layers - 2, default=(100,)
#     The ith element represents the number of neurons in the ith
#     hidden layer.
#
# activation : {'identity', 'logistic', 'tanh', 'relu'}, default='relu'
#     Activation function for the hidden layer.
#
#     - 'identity', no-op activation, useful to implement linear bottleneck,
#       returns f(x) = x
#
#     - 'logistic', the logistic sigmoid function,
#       returns f(x) = 1 / (1 + exp(-x)).
#
# ...
